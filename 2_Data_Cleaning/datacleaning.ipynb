# %%
import pandas as pd

path = r"G:\My Drive\University Files\5th Semester\Data Mining\twitter_sentiment_analysis\2_Data_Cleaning\data\tweets_all_clean_dedup.csv"
df = pd.read_csv(path)

print("Total rows:", len(df))
print("Unique ids:", df["id"].nunique() if "id" in df.columns else "no id column")
print("Unique clean_text:", df["clean_text"].nunique() if "clean_text" in df.columns else "no clean_text column")
# Out:
# Total rows: 74081
# Unique ids: 74081
# Unique clean_text: 74081
